# %% [markdown]
# ## Data Cleaning
#
# The data is taken from the World Bank Gender Statistics dataset, covering 790 features. This mainly relate to gender but also include some more general features such as GDP, GNI and Population. Initially I have chosen just to focus on one year, 2019, due to the time constraints of this project. This year was chosen as it was the most recent year which had complete data for a large number of countries, and avoided the COVID period, which would have the effect of distorting some features.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as pl

# %% [markdown]
# Load the data into a pandas dataframe.

# %%
df=pd.read_csv('Data/wb_gender_data_large.csv')

# %%
df
# Out:
#                                               Series Name     Series Code  \
# 0       A woman can apply for a passport in the same w...  SG.APL.PSPT.EQ
# 1       A woman can apply for a passport in the same w...  SG.APL.PSPT.EQ
# 2       A woman can apply for a passport in the same w...  SG.APL.PSPT.EQ
# 3       A woman can apply for a passport in the same w...  SG.APL.PSPT.EQ
# 4       A woman can apply for a passport in the same w...  SG.APL.PSPT.EQ
# ...                                                   ...             ...
# 170779                                                NaN             NaN
# 170780                                                NaN             NaN
# 170781                                                NaN             NaN
# 170782              Data from database: Gender Statistics             NaN
# 170783                           Last Updated: 04/17/2025             NaN
#
#           Country Name Country Code 2019 [YR2019]
# 0          Afghanistan          AFG             1
# 1              Albania          ALB             1
# 2              Algeria          DZA             0
# 3       American Samoa          ASM            ..
# 4              Andorra          AND            ..
# ...                ...          ...           ...
# 170779             NaN          NaN           NaN
# 170780             NaN          NaN           NaN
# 170781             NaN          NaN           NaN
# 170782             NaN          NaN           NaN
# 170783             NaN          NaN           NaN
#
# [170784 rows x 5 columns]

# %% [markdown]
# Remove the colums with codes for series and country, which are not needed.

# %%
df=df.drop(['Series Code','Country Code'],axis='columns')

# %% [markdown]
# Creating a list of all the unique series names. This can be used to narrow down the field of features to be focused on. Saved to a .csv to be looked at manually.

# %%
series = df['Series Name'].unique()
series = pd.DataFrame(series)
series.to_csv('Data/series_names.csv')
# print(series)
print(type(series))
print(series.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (790, 1)

# %% [markdown]
# Change all empty cells ('..') to NaN, this will allow them to be dealt with during data cleaning.

# %%
(df[df.eq('..')])=np.nan

# %% [markdown]
# Remove the last 5 rows as they do not contain data.

# %%
df = df.iloc[:-5,:]

# %% [markdown]
# Re-order the rows.

# %%
df=df.reindex(columns=['Country Name','Series Name','2019 [YR2019]'])

# %%
df = df.rename(columns={'2019 [YR2019]': '2019 Value'})

# %% [markdown]
# Pivot the data so the series names are shifted to columns. The country name is the index.

# %%
df = df.pivot_table(values='2019 Value', index='Country Name', columns='Series Name',aggfunc='min')

# %% [markdown]
# Make all the values in the dataframe numeric, not strings

# %%
df = df.apply(pd.to_numeric)

# %% [markdown]
# List all countries with under 1 mllion population.

# %%
small_countries = df[df['Population, total'] < 1000000]
print(small_countries.index)
# Out:
# Index(['American Samoa', 'Andorra', 'Antigua and Barbuda', 'Aruba',
#        'Bahamas, The', 'Barbados', 'Belize', 'Bermuda', 'Bhutan',
#        'British Virgin Islands', 'Brunei Darussalam', 'Cabo Verde',
#        'Cayman Islands', 'Channel Islands', 'Comoros', 'Curacao', 'Dominica',
#        'Faroe Islands', 'Fiji', 'French Polynesia', 'Gibraltar', 'Greenland',
#        'Grenada', 'Guam', 'Guyana', 'Iceland', 'Isle of Man', 'Kiribati',
#        'Liechtenstein', 'Luxembourg', 'Macao SAR, China', 'Maldives', 'Malta',
#        'Marshall Islands', 'Micronesia, Fed. Sts.', 'Monaco', 'Montenegro',
#        'Nauru', 'New Caledonia', 'Northern Mariana Islands', 'Palau', 'Samoa',
#        'San Marino', 'Sao Tome and Principe', 'Seychelles',
#        'Sint Maarten (Dutch part)', 'Solomon Islands', 'St. Kitts and Nevis',
#        'St. Lucia', 'St. Martin (French part)',
#        'St. Vincent and the Grenadines', 'Suriname', 'Tonga',
#        'Turks and Caicos Islands', 'Tuvalu', 'Vanuatu',
#        'Virgin Islands (U.S.)'],
#       dtype='object', name='Country Name')

# %% [markdown]
# Remove all countries with population under 1 million.

# %%
df = df[df['Population, total'] > 1000000]

# %% [markdown]
# This is the feature I selected to be the predicted using the machine learning models. I choose this as it seemed a good marker for gender equality within a country. In total, 82 countries had a value for this feature.

# %%
df['Female share of employment in senior and middle management (%)'].describe()
# Out:
# count    82.000000
# mean     32.599878
# std      10.118658
# min       6.326000
# 25%      28.093250
# 50%      32.848500
# 75%      39.163250
# max      61.956000
# Name: Female share of employment in senior and middle management (%), dtype: float64

# %%
df[~df['Female share of employment in senior and middle management (%)'].isna()].index
# Out:
# Index(['Albania', 'Angola', 'Argentina', 'Australia', 'Austria', 'Belarus',
#        'Belgium', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Cambodia', 'Colombia', 'Costa Rica', 'Croatia', 'Cyprus',
#        'Czechia', 'Denmark', 'Dominican Republic', 'Ecuador',
#        'Egypt, Arab Rep.', 'El Salvador', 'Estonia', 'Finland', 'France',
#        'Georgia', 'Germany', 'Greece', 'Guatemala', 'Honduras', 'Hungary',
#        'India', 'Iran, Islamic Rep.', 'Ireland', 'Israel', 'Italy', 'Japan',
#        'Jordan', 'Kenya', 'Kosovo', 'Kyrgyz Republic', 'Latvia', 'Lebanon',
#        'Lesotho', 'Lithuania', 'Mexico', 'Mongolia', 'Myanmar', 'Netherlands',
#        'Nigeria', 'North Macedonia', 'Norway', 'Pakistan', 'Philippines',
#        'Poland', 'Portugal', 'Romania', 'Russian Federation', 'Senegal',
#        'Serbia', 'Slovak Republic', 'Slovenia', 'Somalia', 'South Africa',
#        'Spain', 'Sri Lanka', 'Sweden', 'Switzerland', 'Thailand',
#        'Trinidad and Tobago', 'Tunisia', 'Turkiye', 'Uganda', 'Ukraine',
#        'United Kingdom', 'United States', 'Uruguay', 'Viet Nam',
#        'West Bank and Gaza', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name')

# %% [markdown]
# Drop all countries which have NaN values in the selected feature, 'Female share of employment in senior and middle management (%)'.

# %%
df_select = df.dropna(subset = ['Female share of employment in senior and middle management (%)'])
df_select.shape
# Out:
# (82, 687)

# %% [markdown]
# Remove other features which includes NaN values. This leaves 162 features.

# %%
df_select = df_select.dropna(axis=1)
df_select.shape
# Out:
# (82, 162)

# %%
df_select.to_csv('Data/wb_gender_data_cleaned.csv')

# %%
series_select = df_select.columns
series_select
series_select = pd.DataFrame(series_select)
series_select.to_csv('Data/series_select_names.csv')

# %%
df_select
# Out:
# Series Name         A woman can apply for a passport in the same way as a man (1=yes; 0=no)  \
# Country Name
# Albania                                                           1.0
# Angola                                                            1.0
# Argentina                                                         1.0
# Australia                                                         1.0
# Austria                                                           1.0
# ...                                                               ...
# Uruguay                                                           1.0
# Viet Nam                                                          1.0
# West Bank and Gaza                                                1.0
# Zambia                                                            0.0
# Zimbabwe                                                          1.0
#
# Series Name         A woman can be "head of household" in the same way as a man (1=yes; 0=no)  \
# Country Name
# Albania                                                           1.0
# Angola                                                            1.0
# Argentina                                                         1.0
# Australia                                                         1.0
# Austria                                                           1.0
# ...                                                               ...
# Uruguay                                                           1.0
# Viet Nam                                                          1.0
# West Bank and Gaza                                                1.0
# Zambia                                                            1.0
# Zimbabwe                                                          1.0
#
# Series Name         A woman can choose where to live in the same way as a man (1=yes; 0=no)  \
# Country Name
# Albania                                                           1.0
# Angola                                                            1.0
# Argentina                                                         1.0
# Australia                                                         1.0
# Austria                                                           1.0
# ...                                                               ...
# Uruguay                                                           1.0
# Viet Nam                                                          1.0
# West Bank and Gaza                                                0.0
# Zambia                                                            1.0
# Zimbabwe                                                          1.0
#
# Series Name         A woman can get a job in the same way as a man (1=yes; 0=no)  \
# Country Name
# Albania                                                           1.0
# Angola                                                            1.0
# Argentina                                                         1.0
# Australia                                                         1.0
# Austria                                                           1.0
# ...                                                               ...
# Uruguay                                                           1.0
# Viet Nam                                                          1.0
# West Bank and Gaza                                                0.0
# Zambia                                                            1.0
# Zimbabwe                                                          1.0
#
# Series Name         A woman can obtain a judgment of divorce in the same way as a man (1=yes; 0=no)  \
# Country Name
# Albania                                                           1.0
# Angola                                                            1.0
# Argentina                                                         1.0
# Australia                                                         1.0
# Austria                                                           1.0
# ...                                                               ...
# Uruguay                                                           1.0
# Viet Nam                                                          1.0
# West Bank and Gaza                                                0.0
# Zambia                                                            0.0
# Zimbabwe                                                          0.0
#
# Series Name         A woman can open a bank account in the same way as a man (1=yes; 0=no)  \
# Country Name
# Albania                                                           1.0
# Angola                                                            1.0
# Argentina                                                         1.0
# Australia                                                         1.0
# Austria                                                           1.0
# ...                                                               ...
# Uruguay                                                           1.0
# Viet Nam                                                          1.0
# West Bank and Gaza                                                1.0
# Zambia                                                            1.0
# Zimbabwe                                                          1.0
#
# Series Name         A woman can register a business in the same way as a man (1=yes; 0=no)  \
# Country Name
# Albania                                                           1.0
# Angola                                                            1.0
# Argentina                                                         1.0
# Australia                                                         1.0
# Austria                                                           1.0
# ...                                                               ...
# Uruguay                                                           1.0
# Viet Nam                                                          1.0
# West Bank and Gaza                                                1.0
# Zambia                                                            1.0
# Zimbabwe                                                          1.0
#
# Series Name         A woman can sign a contract in the same way as a man (1=yes; 0=no)  \
# Country Name
# Albania                                                           1.0
# Angola                                                            1.0
# Argentina                                                         1.0
# Australia                                                         1.0
# Austria                                                           1.0
# ...                                                               ...
# Uruguay                                                           1.0
# Viet Nam                                                          1.0
# West Bank and Gaza                                                1.0
# Zambia                                                            1.0
# Zimbabwe                                                          1.0
#
# Series Name         A woman can travel outside her home in the same way as a man (1=yes; 0=no)  \
# Country Name
# Albania                                                           1.0
# Angola                                                            1.0
# Argentina                                                         1.0
# Australia                                                         1.0
# Austria                                                           1.0
# ...                                                               ...
# Uruguay                                                           1.0
# Viet Nam                                                          1.0
# West Bank and Gaza                                                0.0
# Zambia                                                            1.0
# Zimbabwe                                                          1.0
#
# Series Name         A woman can travel outside the country in the same way as a man (1=yes; 0=no)  \
# Country Name
# Albania                                                           1.0
# Angola                                                            1.0
# Argentina                                                         1.0
# Australia                                                         1.0
# Austria                                                           1.0
# ...                                                               ...
# Uruguay                                                           1.0
# Viet Nam                                                          1.0
# West Bank and Gaza                                                0.0
# Zambia                                                            1.0
# Zimbabwe                                                          1.0
#
# Series Name         ...  Time required to start a business, female (days)  \
# Country Name        ...
# Albania             ...                                               4.5
# Angola              ...                                              36.0
# Argentina           ...                                              11.5
# Australia           ...                                               2.0
# Austria             ...                                              21.0
# ...                 ...                                               ...
# Uruguay             ...                                               6.5
# Viet Nam            ...                                              16.0
# West Bank and Gaza  ...                                              44.0
# Zambia              ...                                               8.5
# Zimbabwe            ...                                              27.0
#
# Series Name         Time required to start a business, male (days)  \
# Country Name
# Albania                                                        4.5
# Angola                                                        36.0
# Argentina                                                     11.5
# Australia                                                      2.0
# Austria                                                       21.0
# ...                                                            ...
# Uruguay                                                        6.5
# Viet Nam                                                      16.0
# West Bank and Gaza                                            43.0
# Zambia                                                         8.5
# Zimbabwe                                                      27.0
#
# Series Name         Unemployment, female (% of female labor force) (national estimate)  \
# Country Name
# Albania                                                        11.316
# Angola                                                         16.546
# Argentina                                                      10.691
# Australia                                                       5.099
# Austria                                                         4.424
# ...                                                               ...
# Uruguay                                                        10.640
# Viet Nam                                                        1.597
# West Bank and Gaza                                             41.191
# Zambia                                                          5.224
# Zimbabwe                                                        6.993
#
# Series Name         Unemployment, male (% of male labor force) (national estimate)  \
# Country Name
# Albania                                                        11.585
# Angola                                                         16.446
# Argentina                                                       9.178
# Australia                                                       5.183
# Austria                                                         4.680
# ...                                                               ...
# Uruguay                                                         7.297
# Viet Nam                                                        1.757
# West Bank and Gaza                                             21.349
# Zambia                                                          5.809
# Zimbabwe                                                        7.756
#
# Series Name         Unemployment, total (% of total labor force) (national estimate)  \
# Country Name
# Albania                                                        11.466
# Angola                                                         16.497
# Argentina                                                       9.843
# Australia                                                       5.143
